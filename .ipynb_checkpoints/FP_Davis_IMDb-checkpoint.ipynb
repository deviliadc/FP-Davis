# %%
pip install selenium beautifulsoup4 pandas matplotlib
# Out:
# Requirement already satisfied: selenium in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (4.21.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (4.12.2)
# Requirement already satisfied: pandas in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (3.8.2)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.1.0)
# Requirement already satisfied: trio~=0.17 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from selenium) (2023.11.17)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4) (2.5)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (3.6)
# Requirement already satisfied: outcome in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\user\appdata\local\programs\python\python312\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from selenium.webdriver import Chrome
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from datetime import datetime

# Path to ChromeDriver
path = "D:\\chromedriver-win64\\chromedriver.exe"

# URL to be accessed 
url_most_popular = "https://www.imdb.com/chart/moviemeter/?ref_=nv_mv_mpmb"


# IF YOU WANT TO DO HEADLESS BROWSER, use codes below
options = Options()
options.headless = False  # Change to True if you want to run the browser in headless mode
service = Service(path)

# THIS IS FOR NORMAL BROWSER SESSION (NOT HEADLESS)
# Define browser to get the first URL
browser = webdriver.Chrome(service=service, options=options) 

# Define browser to get the second/detail URL
browser2 = webdriver.Chrome(service=service, options=options)

# Check file availability and content is not empty
filename = "imdb_mostpopular_1.csv"
filename2 = "imdb_mostpopular_2.csv"

def visualize_data():
    print("Visualize Something")
    
if os.path.isfile(filename) and os.path.getsize(filename) > 0:   
    os.remove(filename)
    os.remove(filename2)

# Initialize file handlers outside try block
f = open(filename, "w", encoding="utf-8")
fheaders = "Name,Link\n"
f.write(fheaders)

f2 = open(filename2, "w", encoding="utf-8")
f2headers = "Name,Budget,Gross_US,Opening_Week,Open_Week_Date,Gross_World,Runtime,Color,Sound_Mix,Aspect_Ratio\n"
f2.write(f2headers)

try:
    # Open session for first URL
    browser.get(url_most_popular)
    
    # We are going to have 2 different actions for "browser"
    # 1. Looking for primary data for each movie in the LIST
    # 2. Looking for LIST of movies based on the search and links to detail page
    #    and then run "browser2" to get the page using the link and extract 
    #    additional data for each movie in the LIST

    # ACTION 1
    first_page = BeautifulSoup(browser.page_source, 'html.parser')
    movies = first_page.find_all("div", {"class": "sc-b189961a-0 hBZnfJ cli-children"})
    
    count = 0
    print("PRIMARY DATA")
    print("-----------------------------------")
    for movie in movies:
        count += 1
        name = re.sub(r"\d+. ", "", movie.find("h3", {"class": "ipc-title__text"}).text)
        link_suffix = movie.find("a")["href"]
        link = "https://www.imdb.com" + link_suffix
        
        # print("-----------------------------------")
        print(name + "," + link)  
        f.write(name + "," + link + "\n")
    
    # ACTION 2
    links = browser.find_elements(By.XPATH, '//div[@class="sc-b189961a-0 hBZnfJ cli-children"]')

    count2 = 0
    print("=====================================")
    print("SECONDARY DATA")
    print("panjang ", len(links))
    print("-----------------------------------")
    movie_titles = first_page.find_all("div", {"class": "ipc-title ipc-title--base ipc-title--title ipc-title-link-no-icon ipc-title--on-textPrimary sc-b189961a-9 iALATN cli-title"})

    # Masuk ke link film
    for link, title in zip(links, movie_titles):
        title = re.sub(r"\d+. ", "", title.text)
        print("judul ke-" + str(count2+1) + ": " + title)
        # Menambahkan penundaan sebelum mengambil halaman detail
        time.sleep(1)
        # Menggunakan WebDriverWait untuk menunggu tautan muncul
        WebDriverWait(browser, 10).until(EC.element_to_be_clickable((By.XPATH, '//div[@class="sc-b189961a-0 hBZnfJ cli-children"]')))
        
        count2 += 1
        budget_num = 0
        gross_us_num = 0
        open_week_rev_num = 0
        open_week_date_std = "1900-01-01 00:00:00"
        gross_world_num = 0
        runtime = 0
        color = ""
        sound_mix = ""
        aspect_ratio = ""

        # print("----------------------")
        detail_link = link.find_element(By.TAG_NAME, 'a').get_attribute('href')
        print(count2, detail_link)
        browser2.get(detail_link)

        # BOX OFFICE DATA ON THE 2ND URL
        det_page = browser2.page_source        
        container_rows = BeautifulSoup(det_page, "html.parser")        
        box_office_elements = container_rows.find("div", {"data-testid": "title-boxoffice-section"})
        tech_spech_elements = container_rows.find("div", {"data-testid": "title-techspecs-section"})

        if box_office_elements is not None:
            det_movie1 = box_office_elements.find_all("span", {"class": "ipc-metadata-list-item__list-content-item"})
            det_movie2 = tech_spech_elements.find_all("div", {"class": "ipc-metadata-list-item__content-container"})

            # BOX OFFICE
            if len(det_movie1) > 4:
                budget = det_movie1[0].text
                gross_us = det_movie1[1].text
                open_week_rev = det_movie1[2].text
                open_week_date = det_movie1[3].text            
                gross_world = det_movie1[4].text

                # print("=====================================")
                budget_num = int(re.sub("[A-Z£€₹$,()a-z]", "", budget))
                gross_us_num = int(re.sub("[A-Z£€₹$,()a-z]", "", gross_us))
                open_week_rev_num = int(re.sub("[A-Z£€₹$,()a-z]", "", open_week_rev))
                open_week_date_std = datetime.strptime(open_week_date, "%b %d, %Y")
                gross_world_num = int(re.sub("[A-Z£€₹$,()a-z]", "", gross_world))

                # print("Data has been formatted to standard")
                # print("-----------------------------------")
                print("budget =", budget_num)
                print("gross_us =", gross_us_num)
                print("opening_week_rev =", open_week_rev_num)
                print("opening_week_date =", open_week_date_std)
                print("gross_world =", gross_world_num)

            # TECHNICAL SPECS
            if len(det_movie2) > 3:
                # runtime
                runtime_elems = det_movie2[0]
                if runtime_elems:
                    runtime_text = runtime_elems.get_text(strip=True)  # Ambil teks dari elemen dengan menghilangkan spasi di awal/akhir
                    runtime_text_cleaned = runtime_text.replace("<!-- -->", "") # Bersihkan teks untuk menghilangkan bagian yang tidak diinginkan
                    # Gunakan regex untuk menemukan jam dan menit
                    hours_match = re.search(r'(\d+)\s*hour', runtime_text_cleaned)
                    minutes_match = re.search(r'(\d+)\s*minute', runtime_text_cleaned)
                    hours = int(hours_match.group(1)) if hours_match else 0
                    minutes = int(minutes_match.group(1)) if minutes_match else 0
                    runtime = hours * 60 + minutes
                else:
                    runtime = 0
                
                # color
                color_elem = det_movie2[1].find("a", class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link")
                color = color_elem.text.strip() if color_elem else ""
                
                # sound_mix
                sound_mix_elem = det_movie2[2].find_all("a", class_="ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link")
                if sound_mix_elem:
                    sound_mix = "; ".join([item.text.strip() for item in sound_mix_elem])
                else:
                    sound_mix = ""

                # aspect_ratio
                aspect_ratio_elem = det_movie2[3].find("span", class_="ipc-metadata-list-item__list-content-item")
                aspect_ratio_text = aspect_ratio_elem.text.strip() if aspect_ratio_elem else ""
                aspect_ratio = re.sub(r'\s*:\s*', ' : ', aspect_ratio_text)
            
                print("runtime:", runtime)
                print("color:", color)
                print("sound_mix:", sound_mix)
                print("aspect_ratio:", aspect_ratio)
        
        # Simpan ke CSV
        f2.write(str(title) + "," + str(budget_num) + "," + str(gross_us_num) + "," + str(open_week_rev_num) + "," + str(open_week_date_std) + "," + str(gross_world_num) + "," + str(runtime) + "," + str(color) + "," + str(sound_mix) + "," + str(aspect_ratio) + "\n")
        print("-----------------------------------")
        
except Exception as E:
    print(E)
finally:
    f.close()
    f2.close()
# Out:
# PRIMARY DATA
# -----------------------------------
# Furiosa: A Mad Max Saga,https://www.imdb.com/title/tt12037194/?ref_=chtmvm_t_1
# Hit Man,https://www.imdb.com/title/tt20215968/?ref_=chtmvm_t_2
# Godzilla Minus One,https://www.imdb.com/title/tt23289160/?ref_=chtmvm_t_3
# Bad Boys: Ride or Die,https://www.imdb.com/title/tt4919268/?ref_=chtmvm_t_4
# The Fall Guy,https://www.imdb.com/title/tt1684562/?ref_=chtmvm_t_5
# Civil War,https://www.imdb.com/title/tt17279496/?ref_=chtmvm_t_6
# Venom: The Last Dance,https://www.imdb.com/title/tt16366836/?ref_=chtmvm_t_7
# Under Paris,https://www.imdb.com/title/tt13964390/?ref_=chtmvm_t_8
# The First Omen,https://www.imdb.com/title/tt5672290/?ref_=chtmvm_t_9
# Kingdom of the Planet of the Apes,https://www.imdb.com/title/tt11389872/?ref_=chtmvm_t_10
# Dune: Part Two,https://www.imdb.com/title/tt15239678/?ref_=chtmvm_t_11
# MaXXXine,https://www.imdb.com/title/tt22048412/?ref_=chtmvm_t_12
# The Watchers,https://www.imdb.com/title/tt26736843/?ref_=chtmvm_t_13
# Atlas,https://www.imdb.com/title/tt14856980/?ref_=chtmvm_t_14
# Mad Max: Fury Road,https://www.imdb.com/title/tt1392190/?ref_=chtmvm_t_15
# Alien: Romulus,https://www.imdb.com/title/tt18412256/?ref_=chtmvm_t_16
# Challengers,https://www.imdb.com/title/tt16426418/?ref_=chtmvm_t_17
# IF,https://www.imdb.com/title/tt11152168/?ref_=chtmvm_t_18
# In a Violent Nature,https://www.imdb.com/title/tt30321146/?ref_=chtmvm_t_19
# The Garfield Movie,https://www.imdb.com/title/tt5779228/?ref_=chtmvm_t_20
# The Ministry of Ungentlemanly Warfare,https://www.imdb.com/title/tt5177120/?ref_=chtmvm_t_21
# The Strangers: Chapter 1,https://www.imdb.com/title/tt22050754/?ref_=chtmvm_t_22
# Colors of Evil: Red,https://www.imdb.com/title/tt27578157/?ref_=chtmvm_t_23
# Inside Out 2,https://www.imdb.com/title/tt22022452/?ref_=chtmvm_t_24
# Godzilla x Kong: The New Empire,https://www.imdb.com/title/tt14539740/?ref_=chtmvm_t_25
# Anyone But You,https://www.imdb.com/title/tt26047818/?ref_=chtmvm_t_26
# Deadpool & Wolverine,https://www.imdb.com/title/tt6263850/?ref_=chtmvm_t_27
# Wolfs,https://www.imdb.com/title/tt14257582/?ref_=chtmvm_t_28
# Tarot,https://www.imdb.com/title/tt14088510/?ref_=chtmvm_t_29
# judul ke-1: Furiosa: A Mad Max Saga
# 1 https://www.imdb.com/title/tt12037194/?ref_=chtmvm_t_1
# budget = 168000000
# gross_us = 58670014
# opening_week_rev = 26326462
# opening_week_date = 2024-05-26 00:00:00
# gross_world = 144670014
# runtime: 148
# color: Color
# sound_mix: IMAX 6-Track; Dolby Surround 7.1; Dolby Atmos; Auro 11.1; D-Cinema 96kHz Dolby Surround 7.1; Sonics-DDP; DTS:X; Dolby Digital; 12-Track Digital Sound
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-2: Hit Man
# 2 https://www.imdb.com/title/tt20215968/?ref_=chtmvm_t_2
# runtime: 115
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-3: Godzilla Minus One
# 3 https://www.imdb.com/title/tt23289160/?ref_=chtmvm_t_3
# budget = 15000000
# gross_us = 56418793
# opening_week_rev = 11419975
# opening_week_date = 2023-12-03 00:00:00
# gross_world = 115857413
# runtime: 124
# color: Color
# sound_mix: Dolby Atmos; IMAX 6-Track
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-4: Bad Boys: Ride or Die
# 4 https://www.imdb.com/title/tt4919268/?ref_=chtmvm_t_4
# budget = 100000000
# gross_us = 56527324
# opening_week_rev = 56527324
# opening_week_date = 2024-06-09 00:00:00
# gross_world = 105127324
# runtime: 115
# color: Color
# sound_mix: Dolby Digital; IMAX 6-Track; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-5: The Fall Guy
# 5 https://www.imdb.com/title/tt1684562/?ref_=chtmvm_t_5
# budget = 130000000
# gross_us = 85014265
# opening_week_rev = 27747035
# opening_week_date = 2024-05-05 00:00:00
# gross_world = 165488265
# runtime: 126
# color: Color
# sound_mix: Dolby Atmos; IMAX 6-Track
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-6: Civil War
# 6 https://www.imdb.com/title/tt17279496/?ref_=chtmvm_t_6
# budget = 50000000
# gross_us = 68599741
# opening_week_rev = 25537368
# opening_week_date = 2024-04-14 00:00:00
# gross_world = 114384368
# runtime: 109
# color: Color
# sound_mix: Dolby Digital; IMAX 6-Track; Dolby Atmos
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-7: Venom: The Last Dance
# 7 https://www.imdb.com/title/tt16366836/?ref_=chtmvm_t_7
# -----------------------------------
# judul ke-8: Under Paris
# 8 https://www.imdb.com/title/tt13964390/?ref_=chtmvm_t_8
# -----------------------------------
# judul ke-9: The First Omen
# 9 https://www.imdb.com/title/tt5672290/?ref_=chtmvm_t_9
# budget = 30000000
# gross_us = 20092802
# opening_week_rev = 8353710
# opening_week_date = 2024-04-07 00:00:00
# gross_world = 53718561
# -----------------------------------
# judul ke-10: Kingdom of the Planet of the Apes
# 10 https://www.imdb.com/title/tt11389872/?ref_=chtmvm_t_10
# budget = 160000000
# gross_us = 149791656
# opening_week_rev = 58400788
# opening_week_date = 2024-05-12 00:00:00
# gross_world = 359791656
# runtime: 145
# color: Color
# sound_mix: Dolby Digital; 12-Track Digital Sound; Dolby Atmos; IMAX 6-Track; Dolby Surround 7.1
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-11: Dune: Part Two
# 11 https://www.imdb.com/title/tt15239678/?ref_=chtmvm_t_11
# budget = 190000000
# gross_us = 282144358
# opening_week_rev = 82505391
# opening_week_date = 2024-03-03 00:00:00
# gross_world = 711844358
# -----------------------------------
# judul ke-12: MaXXXine
# 12 https://www.imdb.com/title/tt22048412/?ref_=chtmvm_t_12
# -----------------------------------
# judul ke-13: The Watchers
# 13 https://www.imdb.com/title/tt26736843/?ref_=chtmvm_t_13
# runtime: 102
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-14: Atlas
# 14 https://www.imdb.com/title/tt14856980/?ref_=chtmvm_t_14
# -----------------------------------
# judul ke-15: Mad Max: Fury Road
# 15 https://www.imdb.com/title/tt1392190/?ref_=chtmvm_t_15
# budget = 150000000
# gross_us = 154280290
# opening_week_rev = 45428128
# opening_week_date = 2015-05-17 00:00:00
# gross_world = 380418444
# runtime: 120
# color: Color
# sound_mix: Dolby Digital; Datasat; SDDS; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-16: Alien: Romulus
# 16 https://www.imdb.com/title/tt18412256/?ref_=chtmvm_t_16
# -----------------------------------
# judul ke-17: Challengers
# 17 https://www.imdb.com/title/tt16426418/?ref_=chtmvm_t_17
# budget = 55000000
# gross_us = 49457006
# opening_week_rev = 15011061
# opening_week_date = 2024-04-28 00:00:00
# gross_world = 141757006
# runtime: 131
# color: Color
# sound_mix: Dolby Digital; Dolby Atmos
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-18: IF
# 18 https://www.imdb.com/title/tt11152168/?ref_=chtmvm_t_18
# budget = 110000000
# gross_us = 93365655
# opening_week_rev = 33715801
# opening_week_date = 2024-05-19 00:00:00
# gross_world = 160565655
# runtime: 104
# color: Color
# sound_mix: Dolby Digital; D-Cinema 96kHz 7.1; Auro 11.1; Dolby Atmos; 12-Track Digital Sound; Dolby Surround 7.1
# aspect_ratio: 1 : 1.85 DCP flat
# -----------------------------------
# judul ke-19: In a Violent Nature
# 19 https://www.imdb.com/title/tt30321146/?ref_=chtmvm_t_19
# -----------------------------------
# judul ke-20: The Garfield Movie
# 20 https://www.imdb.com/title/tt5779228/?ref_=chtmvm_t_20
# budget = 60000000
# gross_us = 68616391
# opening_week_rev = 24006629
# opening_week_date = 2024-05-26 00:00:00
# gross_world = 192716391
# runtime: 101
# color: Color
# sound_mix: Dolby Digital; Dolby Atmos; D-Cinema 96kHz 7.1; Dolby Surround 7.1; Auro 11.1; 12-Track Digital Sound; DTS:X
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-21: The Ministry of Ungentlemanly Warfare
# 21 https://www.imdb.com/title/tt5177120/?ref_=chtmvm_t_21
# budget = 60000000
# gross_us = 20535053
# opening_week_rev = 8913698
# opening_week_date = 2024-04-21 00:00:00
# gross_world = 25885290
# runtime: 120
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-22: The Strangers: Chapter 1
# 22 https://www.imdb.com/title/tt22050754/?ref_=chtmvm_t_22
# -----------------------------------
# judul ke-23: Colors of Evil: Red
# 23 https://www.imdb.com/title/tt27578157/?ref_=chtmvm_t_23
# -----------------------------------
# judul ke-24: Inside Out 2
# 24 https://www.imdb.com/title/tt22022452/?ref_=chtmvm_t_24
# -----------------------------------
# judul ke-25: Godzilla x Kong: The New Empire
# 25 https://www.imdb.com/title/tt14539740/?ref_=chtmvm_t_25
# budget = 135000000
# gross_us = 196350016
# opening_week_rev = 80006561
# opening_week_date = 2024-03-31 00:00:00
# gross_world = 567650016
# runtime: 115
# color: Color
# sound_mix: IMAX 6-Track; Dolby Digital; Dolby Surround 7.1; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-26: Anyone But You
# 26 https://www.imdb.com/title/tt26047818/?ref_=chtmvm_t_26
# budget = 25000000
# gross_us = 88319668
# opening_week_rev = 6000344
# opening_week_date = 2023-12-24 00:00:00
# gross_world = 219879736
# -----------------------------------
# judul ke-27: Deadpool & Wolverine
# 27 https://www.imdb.com/title/tt6263850/?ref_=chtmvm_t_27
# -----------------------------------
# judul ke-28: Wolfs
# 28 https://www.imdb.com/title/tt14257582/?ref_=chtmvm_t_28
# -----------------------------------
# judul ke-29: Tarot
# 29 https://www.imdb.com/title/tt14088510/?ref_=chtmvm_t_29
# budget = 8250000
# gross_us = 18326840
# opening_week_rev = 6503012
# opening_week_date = 2024-05-05 00:00:00
# gross_world = 45326840
# -----------------------------------
# judul ke-30: Kinds of Kindness
# 30 https://www.imdb.com/title/tt22408160/?ref_=chtmvm_t_30
# -----------------------------------
# judul ke-31: The Idea of You
# 31 https://www.imdb.com/title/tt9466114/?ref_=chtmvm_t_31
# -----------------------------------
# judul ke-32: Horizon: An American Saga - Chapter 1
# 32 https://www.imdb.com/title/tt17505010/?ref_=chtmvm_t_32
# runtime: 181
# color: Color
# sound_mix: Dolby Digital; Dolby Atmos
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-33: The Bikeriders
# 33 https://www.imdb.com/title/tt21454134/?ref_=chtmvm_t_33
# -----------------------------------
# judul ke-34: Die Hart Die Harter
# 34 https://www.imdb.com/title/tt32094375/?ref_=chtmvm_t_34
# -----------------------------------
# judul ke-35: The Iron Claw
# 35 https://www.imdb.com/title/tt21064584/?ref_=chtmvm_t_35
# budget = 15000000
# gross_us = 35070296
# opening_week_rev = 4868370
# opening_week_date = 2023-12-24 00:00:00
# gross_world = 45200720
# runtime: 132
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-36: Dune
# 36 https://www.imdb.com/title/tt1160419/?ref_=chtmvm_t_36
# budget = 165000000
# gross_us = 108897830
# opening_week_rev = 41011174
# opening_week_date = 2021-10-24 00:00:00
# gross_world = 407573628
# runtime: 155
# color: Color
# sound_mix: Auro 11.1; Dolby Surround 7.1; Dolby Atmos; Dolby Digital; IMAX 6-Track
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-37: The Crow
# 37 https://www.imdb.com/title/tt1340094/?ref_=chtmvm_t_37
# -----------------------------------
# judul ke-38: Madame Web
# 38 https://www.imdb.com/title/tt11057302/?ref_=chtmvm_t_38
# budget = 80000000
# gross_us = 43817106
# opening_week_rev = 15335860
# opening_week_date = 2024-02-18 00:00:00
# gross_world = 100298817
# runtime: 116
# color: Color
# sound_mix: IMAX 6-Track; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-39: Am I OK?
# 39 https://www.imdb.com/title/tt11225626/?ref_=chtmvm_t_39
# -----------------------------------
# judul ke-40: X
# 40 https://www.imdb.com/title/tt13560574/?ref_=chtmvm_t_40
# budget = 1000000
# gross_us = 11765309
# opening_week_rev = 4275126
# opening_week_date = 2022-03-20 00:00:00
# gross_world = 14740889
# runtime: 105
# color: Color
# sound_mix: Dolby Atmos; Dolby Digital
# aspect_ratio: 1.90 : 1
# -----------------------------------
# judul ke-41: The Hunger Games: The Ballad of Songbirds & Snakes
# 41 https://www.imdb.com/title/tt10545296/?ref_=chtmvm_t_41
# budget = 100000000
# gross_us = 166350594
# opening_week_rev = 44607143
# opening_week_date = 2023-11-19 00:00:00
# gross_world = 337371917
# runtime: 157
# color: Color
# sound_mix: DTS; Dolby Atmos; IMAX 6-Track; Dolby Surround 7.1; Dolby Digital; 12-Track Digital Sound; Auro 11.1; DTS:X; D-Cinema 96kHz 7.1
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-42: The Boys in the Boat
# 42 https://www.imdb.com/title/tt1856080/?ref_=chtmvm_t_42
# budget = 40000000
# gross_us = 52641306
# opening_week_rev = 8400548
# opening_week_date = 2023-12-31 00:00:00
# gross_world = 55481773
# runtime: 123
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-43: Oppenheimer
# 43 https://www.imdb.com/title/tt15398776/?ref_=chtmvm_t_43
# budget = 100000000
# gross_us = 329862540
# opening_week_rev = 82455420
# opening_week_date = 2023-07-23 00:00:00
# gross_world = 974954311
# -----------------------------------
# judul ke-44: Abigail
# 44 https://www.imdb.com/title/tt27489557/?ref_=chtmvm_t_44
# budget = 28000000
# gross_us = 25867515
# opening_week_rev = 10297110
# opening_week_date = 2024-04-21 00:00:00
# gross_world = 42080515
# -----------------------------------
# judul ke-45: Boy Kills World
# 45 https://www.imdb.com/title/tt13923084/?ref_=chtmvm_t_45
# -----------------------------------
# judul ke-46: Saving Private Ryan
# 46 https://www.imdb.com/title/tt0120815/?ref_=chtmvm_t_46
# budget = 70000000
# gross_us = 217049603
# opening_week_rev = 30576104
# opening_week_date = 1998-07-26 00:00:00
# gross_world = 482351251
# runtime: 169
# color: Color
# sound_mix: DTS; Dolby Digital; SDDS; Dolby Atmos; Dolby Digital EX; Dolby Stereo
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-47: Poor Things
# 47 https://www.imdb.com/title/tt14230458/?ref_=chtmvm_t_47
# budget = 35000000
# gross_us = 34553225
# opening_week_rev = 661230
# opening_week_date = 2023-12-10 00:00:00
# gross_world = 117607117
# runtime: 141
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 1.66 : 1
# -----------------------------------
# judul ke-48: Late Night with the Devil
# 48 https://www.imdb.com/title/tt14966898/?ref_=chtmvm_t_48
# -----------------------------------
# judul ke-49: Mad Max
# 49 https://www.imdb.com/title/tt0079501/?ref_=chtmvm_t_49
# -----------------------------------
# judul ke-50: What You Wish For
# 50 https://www.imdb.com/title/tt13638858/?ref_=chtmvm_t_50
# -----------------------------------
# judul ke-51: Inside Out
# 51 https://www.imdb.com/title/tt2096673/?ref_=chtmvm_t_51
# budget = 175000000
# gross_us = 356921711
# opening_week_rev = 90440272
# opening_week_date = 2015-06-21 00:00:00
# gross_world = 858852998
# runtime: 95
# color: Color
# sound_mix: Dolby Digital; Datasat; Dolby Atmos; SDDS; Dolby Surround 7.1; Auro 11.1; 12-Track Digital Sound; D-Cinema 48kHz Dolby Surround 7.1; D-Cinema 96kHz 7.1; D-Cinema 96kHz 5.1
# aspect_ratio: 1.78 : 1
# -----------------------------------
# judul ke-52: The Longest Day
# 52 https://www.imdb.com/title/tt0056197/?ref_=chtmvm_t_52
# -----------------------------------
# judul ke-53: Sister Act Back in the Habit
# 53 https://www.imdb.com/title/tt0108147/?ref_=chtmvm_t_53
# budget = 38000000
# gross_us = 57319029
# opening_week_rev = 7569219
# opening_week_date = 1993-12-12 00:00:00
# gross_world = 57319029
# runtime: 107
# color: Color
# sound_mix: Dolby Stereo
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-54: Road House
# 54 https://www.imdb.com/title/tt3359350/?ref_=chtmvm_t_54
# runtime: 121
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-55: Love Lies Bleeding
# 55 https://www.imdb.com/title/tt19637052/?ref_=chtmvm_t_55
# -----------------------------------
# judul ke-56: Mother of the Bride
# 56 https://www.imdb.com/title/tt26926267/?ref_=chtmvm_t_56
# -----------------------------------
# judul ke-57: Mad Max The Road Warrior
# 57 https://www.imdb.com/title/tt0082694/?ref_=chtmvm_t_57
# budget = 3000000
# gross_us = 23667907
# opening_week_rev = 2527864
# opening_week_date = 1982-05-23 00:00:00
# gross_world = 23668605
# -----------------------------------
# judul ke-58: Bad Boys for Life
# 58 https://www.imdb.com/title/tt1502397/?ref_=chtmvm_t_58
# budget = 90000000
# gross_us = 206305244
# opening_week_rev = 62504105
# opening_week_date = 2020-01-19 00:00:00
# gross_world = 426505244
# runtime: 124
# color: Color
# sound_mix: Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-59: Bullet Train
# 59 https://www.imdb.com/title/tt12593682/?ref_=chtmvm_t_59
# budget = 85900000
# gross_us = 103368602
# opening_week_rev = 30030156
# opening_week_date = 2022-08-07 00:00:00
# gross_world = 239268602
# runtime: 127
# color: Color
# sound_mix: Dolby Atmos; Auro 11.1; IMAX 6-Track
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-60: Bad Boys
# 60 https://www.imdb.com/title/tt0112442/?ref_=chtmvm_t_60
# budget = 19000000
# gross_us = 65807024
# opening_week_rev = 15523358
# opening_week_date = 1995-04-09 00:00:00
# gross_world = 141407024
# runtime: 119
# color: Color
# sound_mix: Dolby SR; SDDS; Dolby Atmos; Dolby Digital
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-61: Unfrosted
# 61 https://www.imdb.com/title/tt14914430/?ref_=chtmvm_t_61
# runtime: 97
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-62: Twisters
# 62 https://www.imdb.com/title/tt12584954/?ref_=chtmvm_t_62
# runtime: 122
# color: Color
# sound_mix: Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-63: Back to Black
# 63 https://www.imdb.com/title/tt21261712/?ref_=chtmvm_t_63
# -----------------------------------
# judul ke-64: The Shawshank Redemption
# 64 https://www.imdb.com/title/tt0111161/?ref_=chtmvm_t_64
# budget = 25000000
# gross_us = 28767189
# opening_week_rev = 727327
# opening_week_date = 1994-09-25 00:00:00
# gross_world = 29322669
# -----------------------------------
# judul ke-65: Beetlejuice Beetlejuice
# 65 https://www.imdb.com/title/tt2049403/?ref_=chtmvm_t_65
# -----------------------------------
# judul ke-66: The Beekeeper
# 66 https://www.imdb.com/title/tt15314262/?ref_=chtmvm_t_66
# budget = 40000000
# gross_us = 66220535
# opening_week_rev = 16576007
# opening_week_date = 2024-01-14 00:00:00
# gross_world = 152720535
# -----------------------------------
# judul ke-67: A Part of You
# 67 https://www.imdb.com/title/tt27411270/?ref_=chtmvm_t_67
# -----------------------------------
# judul ke-68: Megalopolis
# 68 https://www.imdb.com/title/tt10128846/?ref_=chtmvm_t_68
# runtime: 138
# color: Color
# sound_mix: Dolby Digital; IMAX 6-Track
# aspect_ratio: 2.00 : 1
# -----------------------------------
# judul ke-69: Ghostbusters: Frozen Empire
# 69 https://www.imdb.com/title/tt21235248/?ref_=chtmvm_t_69
# budget = 100000000
# gross_us = 113125852
# opening_week_rev = 45004673
# opening_week_date = 2024-03-24 00:00:00
# gross_world = 201305371
# runtime: 115
# color: Color
# sound_mix: IMAX 6-Track; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-70: A Quiet Place: Day One
# 70 https://www.imdb.com/title/tt13433802/?ref_=chtmvm_t_70
# -----------------------------------
# judul ke-71: Argylle
# 71 https://www.imdb.com/title/tt15009428/?ref_=chtmvm_t_71
# budget = 200000000
# gross_us = 45207275
# opening_week_rev = 17473540
# opening_week_date = 2024-02-04 00:00:00
# gross_world = 96185778
# runtime: 139
# color: Color
# sound_mix: Dolby Digital; IMAX 6-Track; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-72: Pearl
# 72 https://www.imdb.com/title/tt18925334/?ref_=chtmvm_t_72
# runtime: 103
# color: Color
# sound_mix: Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-73: Once Upon a Time... in Hollywood
# 73 https://www.imdb.com/title/tt7131622/?ref_=chtmvm_t_73
# budget = 90000000
# gross_us = 142502728
# opening_week_rev = 41082018
# opening_week_date = 2019-07-28 00:00:00
# gross_world = 377617681
# runtime: 161
# color: Color
# sound_mix: Dolby Digital; Dolby Atmos; Dolby Surround 7.1
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-74: The Gentlemen
# 74 https://www.imdb.com/title/tt8367814/?ref_=chtmvm_t_74
# budget = 22000000
# gross_us = 36471795
# opening_week_rev = 10651884
# opening_week_date = 2020-01-26 00:00:00
# gross_world = 115175729
# runtime: 113
# color: Color
# sound_mix: Dolby Digital; Dolby Surround 7.1; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-75: The Godfather
# 75 https://www.imdb.com/title/tt0068646/?ref_=chtmvm_t_75
# budget = 6000000
# gross_us = 136381073
# opening_week_rev = 302393
# opening_week_date = 1972-03-19 00:00:00
# gross_world = 250342030
# runtime: 175
# color: Color
# sound_mix: Mono; Dolby Digital
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-76: Top Gun: Maverick
# 76 https://www.imdb.com/title/tt1745960/?ref_=chtmvm_t_76
# budget = 170000000
# gross_us = 718732821
# opening_week_rev = 126707459
# opening_week_date = 2022-05-29 00:00:00
# gross_world = 1495696292
# runtime: 130
# color: Color
# sound_mix: Dolby Atmos; Auro 11.1; IMAX 6-Track; 12-Track Digital Sound; Sonics-DDP
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-77: I Saw the TV Glow
# 77 https://www.imdb.com/title/tt15574270/?ref_=chtmvm_t_77
# runtime: 100
# color: Color
# sound_mix: Dolby Atmos; Dolby Digital
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-78: A Million Ways to Die in the West
# 78 https://www.imdb.com/title/tt2557490/?ref_=chtmvm_t_78
# budget = 40000000
# gross_us = 43139300
# opening_week_rev = 16797385
# opening_week_date = 2014-06-01 00:00:00
# gross_world = 87189756
# runtime: 116
# color: Color
# sound_mix: SDDS; Datasat; Dolby Digital
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-79: Mr. & Mrs. Mahi
# 79 https://www.imdb.com/title/tt16227342/?ref_=chtmvm_t_79
# -----------------------------------
# judul ke-80: Interstellar
# 80 https://www.imdb.com/title/tt0816692/?ref_=chtmvm_t_80
# budget = 165000000
# gross_us = 188020017
# opening_week_rev = 47510360
# opening_week_date = 2014-11-09 00:00:00
# gross_world = 747516808
# runtime: 169
# color: Color
# sound_mix: Datasat; Dolby Digital; IMAX 6-Track; Dolby Surround 7.1
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-81: Moana 2
# 81 https://www.imdb.com/title/tt13622970/?ref_=chtmvm_t_81
# -----------------------------------
# judul ke-82: 1917
# 82 https://www.imdb.com/title/tt8579674/?ref_=chtmvm_t_82
# budget = 95000000
# gross_us = 159227644
# opening_week_rev = 576216
# opening_week_date = 2019-12-29 00:00:00
# gross_world = 384580017
# runtime: 119
# color: Color
# sound_mix: Dolby Atmos; Dolby Digital; Dolby Surround 7.1
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-83: Immaculate
# 83 https://www.imdb.com/title/tt23137390/?ref_=chtmvm_t_83
# budget = 9000000
# gross_us = 15671307
# opening_week_rev = 5338921
# opening_week_date = 2024-03-24 00:00:00
# gross_world = 25799625
# -----------------------------------
# judul ke-84: Mean Girls
# 84 https://www.imdb.com/title/tt11762114/?ref_=chtmvm_t_84
# budget = 36000000
# gross_us = 72404248
# opening_week_rev = 28635307
# opening_week_date = 2024-01-14 00:00:00
# gross_world = 104404248
# runtime: 112
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 1.85 : 1
# -----------------------------------
# judul ke-85: My Fault
# 85 https://www.imdb.com/title/tt21909764/?ref_=chtmvm_t_85
# -----------------------------------
# judul ke-86: The Dead Don't Hurt
# 86 https://www.imdb.com/title/tt22773644/?ref_=chtmvm_t_86
# runtime: 129
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 2.35 : 1
# -----------------------------------
# judul ke-87: Barbie
# 87 https://www.imdb.com/title/tt1517268/?ref_=chtmvm_t_87
# budget = 100000000
# gross_us = 636238421
# opening_week_rev = 162022044
# opening_week_date = 2023-07-23 00:00:00
# gross_world = 1445638421
# runtime: 114
# color: Color
# sound_mix: Dolby Digital; IMAX 6-Track; 12-Track Digital Sound; D-Cinema 96kHz 7.1; Auro 11.1; Dolby Atmos; DTS:X
# aspect_ratio: 2.00 : 1
# -----------------------------------
# judul ke-88: A Simple Favor
# 88 https://www.imdb.com/title/tt7040874/?ref_=chtmvm_t_88
# budget = 20000000
# gross_us = 53548586
# opening_week_rev = 16011689
# opening_week_date = 2018-09-16 00:00:00
# gross_world = 97644617
# runtime: 117
# color: Color
# sound_mix: Dolby Surround 7.1
# aspect_ratio: 2.00 : 1
# -----------------------------------
# judul ke-89: War for the Planet of the Apes
# 89 https://www.imdb.com/title/tt3450958/?ref_=chtmvm_t_89
# budget = 150000000
# gross_us = 146880162
# opening_week_rev = 56262929
# opening_week_date = 2017-07-16 00:00:00
# gross_world = 490719763
# runtime: 140
# color: Color
# sound_mix: Dolby Atmos; Dolby Digital; Auro 11.1; IMAX 6-Track; Dolby Surround 7.1
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-90: Ezra
# 90 https://www.imdb.com/title/tt20315818/?ref_=chtmvm_t_90
# -----------------------------------
# judul ke-91: Monkey Man
# 91 https://www.imdb.com/title/tt9214772/?ref_=chtmvm_t_91
# budget = 10000000
# gross_us = 25116955
# opening_week_rev = 10119435
# opening_week_date = 2024-04-07 00:00:00
# gross_world = 34659562
# runtime: 121
# color: Color
# sound_mix: Dolby Atmos; 12-Track Digital Sound; Dolby Digital; DTS:X; Dolby Surround 7.1; Auro 11.1
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-92: American Graffiti
# 92 https://www.imdb.com/title/tt0069704/?ref_=chtmvm_t_92
# -----------------------------------
# judul ke-93: Longlegs
# 93 https://www.imdb.com/title/tt23468450/?ref_=chtmvm_t_93
# -----------------------------------
# judul ke-94: Pulp Fiction
# 94 https://www.imdb.com/title/tt0110912/?ref_=chtmvm_t_94
# budget = 8000000
# gross_us = 107928762
# opening_week_rev = 9311882
# opening_week_date = 1994-10-16 00:00:00
# gross_world = 213928762
# runtime: 154
# color: Color
# sound_mix: Dolby Digital; DTS
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-95: Miller's Girl
# 95 https://www.imdb.com/title/tt8310486/?ref_=chtmvm_t_95
# -----------------------------------
# judul ke-96: The Zone of Interest
# 96 https://www.imdb.com/title/tt7160372/?ref_=chtmvm_t_96
# runtime: 105
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 1.78 : 1
# -----------------------------------
# judul ke-97: Laapataa Ladies
# 97 https://www.imdb.com/title/tt21626284/?ref_=chtmvm_t_97
# -----------------------------------
# judul ke-98: The Omen
# 98 https://www.imdb.com/title/tt0075005/?ref_=chtmvm_t_98
# budget = 2800000
# gross_us = 60922980
# opening_week_rev = 4273886
# opening_week_date = 1976-06-27 00:00:00
# gross_world = 60922980
# runtime: 111
# color: Color
# sound_mix: Mono
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-99: Crew
# 99 https://www.imdb.com/title/tt21383812/?ref_=chtmvm_t_99
# runtime: 118
# color: Color
# sound_mix: Dolby Digital; Dolby Atmos
# aspect_ratio: 2.39 : 1
# -----------------------------------
# judul ke-100: American Fiction
# 100 https://www.imdb.com/title/tt23561236/?ref_=chtmvm_t_100
# runtime: 117
# color: Color
# sound_mix: Dolby Digital
# aspect_ratio: 2.39 : 1
# -----------------------------------

# %%
import pandas as pd
filename1 = "imdb_mostpopular_1.csv"
filename2 = "imdb_mostpopular_2.csv"

filename3 = 'imdb_mostpopular_combined.csv'

if os.path.isfile(filename3) and os.path.getsize(filename3) > 0:      
    os.remove(filename3)
    
# Read CSV files into dataframes
df1 = pd.read_csv(filename1)
df2 = pd.read_csv(filename2)

merged = df1.merge(df2,on='Name')
merged.to_csv("imdb_mostpopular_combined.csv", index=False)

# Display the first few rows of the combined data
print(merged.head())
# Out:
#                       Name                                               Link  \
# 0  Furiosa: A Mad Max Saga  https://www.imdb.com/title/tt12037194/?ref_=ch...
# 1                  Hit Man  https://www.imdb.com/title/tt20215968/?ref_=ch...
# 2       Godzilla Minus One  https://www.imdb.com/title/tt23289160/?ref_=ch...
# 3    Bad Boys: Ride or Die  https://www.imdb.com/title/tt4919268/?ref_=cht...
# 4             The Fall Guy  https://www.imdb.com/title/tt1684562/?ref_=cht...
#
#       Budget  Gross_US  Opening_Week       Open_Week_Date  Gross_World  \
# ..                                                ...          ...
# 95                                      Dolby Digital     1.78 : 1
# 96                                                NaN          NaN
# 97                                               Mono     2.39 : 1
# 98                         Dolby Digital; Dolby Atmos     2.39 : 1
# 99                                      Dolby Digital     2.39 : 1
#
# [100 rows x 11 columns]

# %%
# DATA TYPE
print(data.dtypes)
# Out:
# Name              object
# Link              object
# Budget             int64
# Gross_US           int64
# Opening_Week       int64
# Open_Week_Date    object
# Gross_World        int64
# Runtime            int64
# Color             object
# Sound_Mix         object
# Aspect_Ratio      object
# dtype: object

# %%
# cek data missing value
data.isnull().sum()
# Out:
# Name               0
# Link               0
# Budget             0
# Gross_US           0
# Opening_Week       0
# Open_Week_Date     0
# Gross_World        0
# Runtime            0
# Color             46
# Sound_Mix         46
# Aspect_Ratio      46
# dtype: int64

# %%
data_clean = data.dropna()

# %%
data_clean = data_clean[data_clean['Budget'] != 0]

# %%
# Periksa jumlah nilai yang hilang setelah pembersihan
print(data_clean.isnull().sum())

# Periksa apakah ada nilai budget yang nol setelah pembersihan
print(data_clean[data_clean['Budget'] == 0])
# Out:
# Name              0
# Link              0
# Budget            0
# Gross_US          0
# Opening_Week      0
# Open_Week_Date    0
# Gross_World       0
# Runtime           0
# Color             0
# Sound_Mix         0
# Aspect_Ratio      0
# dtype: int64
# Empty DataFrame
# Columns: [Name, Link, Budget, Gross_US, Opening_Week, Open_Week_Date, Gross_World, Runtime, Color, Sound_Mix, Aspect_Ratio]
# Index: []

# %%
data_clean
# Out:
#                                                  Name  \
# 0                             Furiosa: A Mad Max Saga
# 2                                  Godzilla Minus One
# 3                               Bad Boys: Ride or Die
# 4                                        The Fall Guy
# 5                                           Civil War
# 9                   Kingdom of the Planet of the Apes
# 14                                 Mad Max: Fury Road
# 16                                        Challengers
# 17                                                 IF
# 19                                 The Garfield Movie
# 20              The Ministry of Ungentlemanly Warfare
# 24                    Godzilla x Kong: The New Empire
# 34                                      The Iron Claw
# 35                                               Dune
# 37                                         Madame Web
# 39                                                  X
# 40  The Hunger Games: The Ballad of Songbirds & Sn...
# 41                               The Boys in the Boat
# 45                                Saving Private Ryan
# 46                                        Poor Things
# 50                                         Inside Out
# 52                       Sister Act Back in the Habit
# 57                                  Bad Boys for Life
# 58                                       Bullet Train
# 59                                           Bad Boys
# 68                        Ghostbusters: Frozen Empire
# 70                                            Argylle
# 72                   Once Upon a Time... in Hollywood
# 73                                      The Gentlemen
# 74                                      The Godfather
# 75                                  Top Gun: Maverick
# 77                  A Million Ways to Die in the West
# 79                                       Interstellar
# 81                                               1917
# 83                                         Mean Girls
# 86                                             Barbie
# 87                                     A Simple Favor
# 88                     War for the Planet of the Apes
# 90                                         Monkey Man
# 93                                       Pulp Fiction
# 97                                           The Omen
#
#                                                  Link     Budget   Gross_US  \
# 0   https://www.imdb.com/title/tt12037194/?ref_=ch...  168000000   58670014
# 2   https://www.imdb.com/title/tt23289160/?ref_=ch...   15000000   56418793
# 33     Dolby Atmos; Dolby Digital; Dolby Surround 7.1           2.39 : 1
# 34                                      Dolby Digital           1.85 : 1
# 35  Dolby Digital; IMAX 6-Track; 12-Track Digital ...           2.00 : 1
# 36                                 Dolby Surround 7.1           2.00 : 1
# 37  Dolby Atmos; Dolby Digital; Auro 11.1; IMAX 6-...           2.39 : 1
# 38  Dolby Atmos; 12-Track Digital Sound; Dolby Dig...           2.39 : 1
# 39                                 Dolby Digital; DTS           2.39 : 1
# 40                                               Mono           2.39 : 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Menghitung jumlah film untuk setiap aspect ratio
aspect_ratio_counts = data['Aspect_Ratio'].value_counts()

# Plotting pie chart
plt.figure(figsize=(6, 6))
plt.pie(aspect_ratio_counts, labels=aspect_ratio_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Aspect Ratio Composition of Most Popular IMDb Films')
plt.axis('equal')  # Mengatur aspek ratio pie chart agar terlihat seperti lingkaran
plt.show()

# %%
# Visualisasi COMPARISON
plt.figure(figsize=(10, 6))
sns.barplot(data=data[['Budget', 'Gross_US', 'Gross_World']], palette='viridis', errorbar=None)
plt.title('Comparison of Budget, Gross US, and Gross World')
plt.xlabel('Features')
plt.ylabel('Amount')
plt.xticks(rotation=45)
plt.show()

# %%
from collections import defaultdict
import numpy as np

# Dictionary to count the occurrences of each sound mix type
sound_mix_counts = defaultdict(int)

# Iterate through the list of sound mixes for each film
for sound_mix_str in data['Sound_Mix']:
    if isinstance(sound_mix_str, str):  # Check if the value is a string
        sound_mixes = sound_mix_str.split(';')
        for sound_mix in sound_mixes:
            sound_mix_counts[sound_mix.strip()] += 1
    elif isinstance(sound_mix_str, float) and np.isnan(sound_mix_str):  # Check if the value is NaN
        # Handling if the value is NaN
        pass
    else:
        print("Value Error:", sound_mix_str)

# Create visualization
plt.figure(figsize=(10, 6))
plt.bar(sound_mix_counts.keys(), sound_mix_counts.values(), color='skyblue')
plt.xlabel('Sound Mix Type')
plt.ylabel('Number of Films')
plt.title('Number of Films Based on Sound Mix Type')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data
budget = data['Budget']
gross_us = data['Gross_World']

# Buat scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(budget, gross_us, color='skyblue', alpha=0.5)
plt.title('Relationship of Budgets and Gross Income Worldwide')
plt.xlabel('Budget (USD)')
plt.ylabel('Gross World Revenue')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Scatter plot: Budget vs. Opening Week Revenue
plt.figure(figsize=(10, 6))
plt.scatter(data_clean['Budget'], data_clean['Opening_Week'], color='skyblue', alpha=0.5)
plt.title('Scatter Plot: Budget vs. Opening Week Revenue')
plt.xlabel('Budget (USD)')
plt.ylabel('Opening Week Revenue (USD)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Scatter plot: Budget vs. Runtime
plt.figure(figsize=(10, 6))
plt.scatter(data_clean['Budget'], data_clean['Runtime'], color='orange', alpha=0.5)
plt.title('Scatter Plot: Budget vs. Runtime')
plt.xlabel('Budget (USD)')
plt.ylabel('Runtime (minutes)')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Visualisasi DISTRIBUTION
plt.figure(figsize=(8, 6))
sns.histplot(data['Runtime'], kde=True)
plt.title('Distribution of IMDb\'s Most Popular Movie Runtime')
plt.xlabel('Runtime (Minutes)')
plt.ylabel('Frequency')
plt.show()
